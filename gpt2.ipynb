# %%
import gpt_2_simple as gpt2

# %%
#gpt2.download_gpt2(model_name='124M')
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 1.99Git/s]
# Fetching encoder.json: 1.05Mit [00:04, 241kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 5.32Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [14:27, 574kit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 4.28Git/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 2.79Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:01, 568kit/s]

# %%
session=gpt2.start_tf_sess()

# %%
gpt2.finetune(session, "shakespeare.txt", model_name="124M", steps="5")
# Out:
# 2023-12-14 09:51:55.777288: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.50it/s]
# dataset has 338024 tokens
# Training...
# [1 | 18.30] loss=4.19 avg=4.19
# [2 | 37.46] loss=3.57 avg=3.88
# [3 | 55.62] loss=3.73 avg=3.83
# [4 | 73.91] loss=3.77 avg=3.81
# [5 | 91.80] loss=3.63 avg=3.78
# Saving checkpoint/run1/model-5

# %%
gpt2.generate(session, prefix="Mr.Forlenza: Thou shall not pass", length=)
# Out:
# Mr.Forlenza: Thou shall not pass up a man's hand,
# less of what he hath done;
# and thou shalt not pass up a man's hand,
# less of what he hath done!
#
#
#
#
#
#
#
# AND
#
#
# And
#
# I shall not pass up a man's hand,
# less of what he hath done;
# and thou shalt not pass up a man's hand,less of what he hath done
#
# apparently
#
# an argument
# to the subject,
# but
# the case is
# not
# quite
# clear,
#
# and the
# case was
# not
# quite clear
#
#
# and the
# case was
# not clear
#
#
#
# so
# to end this debate,
# I should like to suggest some others,
# not quite so
# clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so
# clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so
# clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so
# clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear, as
# to
# enjoy
# the
# success of
# the
# debate,
# as
# I should like to suggest some others,
# not quite so clear
